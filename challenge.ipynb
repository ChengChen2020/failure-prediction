# %%
import pandas as pd
from numpy.random import RandomState
from sklearn.preprocessing import StandardScaler

import torch
from torch.utils.data import Dataset, DataLoader

# %%
data = pd.read_csv('train_data.csv')
rng = RandomState()

trainRaw = data.sample(frac=0.95, random_state=rng)
valRaw = data.loc[~data.index.isin(trainRaw.index)]

# trainRaw_1 = trainRaw[trainRaw['failed'] == 1] # 1328
# trainRaw_0 = trainRaw[trainRaw['failed'] == 0].sample(frac=0.1, random_state=rng) 
# trainRaw = pd.concat([trainRaw_1, trainRaw_0])

# %%
trainRaw_1 = trainRaw[trainRaw['failed'] == 1]
trainRaw_0 = trainRaw[trainRaw['failed'] == 0]
print(len(trainRaw_1))
print(len(trainRaw_0))
# Out:
# 1540
# 17460

# %%
class MyDataset(Dataset):
    def __init__(self, dataRaw):
        x = dataRaw.iloc[:, 1:-1].values
        y = dataRaw.iloc[:, -1].values
        sc = StandardScaler()
        self.X = torch.tensor(sc.fit_transform(x), dtype=torch.float32)
#         self.X = torch.tensor(x, dtype=torch.float32)
        self.Y = torch.tensor(y)
        
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
trainData = MyDataset(trainRaw)
valData = MyDataset(valRaw)

# 0.08

# %%
class MyNet(torch.nn.Module):
    def __init__(self, hidden = 128):
        super(MyNet, self).__init__()
        self.linear1 = torch.nn.Linear(4,       hidden)
        self.linear2 = torch.nn.Linear(hidden,  hidden)
        self.linear3 = torch.nn.Linear(hidden,       2)
        self.relu    = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p = 0.5)

    def forward(self, x):
        x = self.relu(self.linear1(x))
        x = self.dropout(self.relu(self.linear2(x)))
        x = self.linear3(x)
        return x

net = MyNet().cuda()
Loss = torch.nn.CrossEntropyLoss(weight=torch.tensor([0.1, 1.2])).cuda()
optimizer = torch.optim.Adam(net.parameters(), lr=5e-4)

nepochs = 300
batch_size = 64
trainDataLoader = DataLoader(trainData, batch_size=batch_size, shuffle=True, drop_last=True)
valDataLoader = DataLoader(valData, batch_size=batch_size, shuffle=False, drop_last=True)

# %%
best_val_acc = 0.0

for epoch in range(nepochs):
    train_class_correct = [0., 0.]
    train_class_total = [0., 0.]
    correct_points_train = 0
    
    val_class_correct = [0., 0.]
    val_class_total = [0., 0.]
    correct_points_val = 0

    train_loss = 0.0
    
    net.train()
    for i, data in enumerate(trainDataLoader):
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()
        
        optimizer.zero_grad()
        predicted_output = net(inputs)
        
        correct_points_train += (torch.eq(torch.max(predicted_output, 1)[1], labels).sum()).data.cpu().numpy()

        c = (torch.max(predicted_output, 1)[1] == labels).squeeze()
        
        for i in range(64):
            label = labels[i]
            train_class_correct[label] += c[i].item()
            train_class_total[label] += 1
        
        fit = Loss(predicted_output, labels)
        fit.backward()
        optimizer.step()
        train_loss += fit.item()
    
    net.eval()
    for i, data in enumerate(valDataLoader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.cuda(), labels.cuda()

            predicted_output = net(inputs)
    
            correct_points_val += (torch.eq(torch.max(predicted_output, 1)[1], labels).sum()).data.cpu().numpy()
        
            c = (torch.max(predicted_output, 1)[1] == labels).squeeze()
        
            for i in range(64):
                label = labels[i]
                val_class_correct[label] += c[i].item()
                val_class_total[label] += 1
            
    train_loss = train_loss / len(trainDataLoader)

    train_acc = correct_points_train * 100. / (len(trainDataLoader) * batch_size)
    val_acc = correct_points_val * 100. / (len(valDataLoader) * batch_size)
    
    train_avg_acc = 0.0
    val_avg_acc = 0.0
    
    for i in range(2):
        train_avg_acc += 100 * train_class_correct[i] / train_class_total[i]
        val_avg_acc += 100 * val_class_correct[i] / val_class_total[i]
        # print('Accuracy of %5s : %2d %%' % (
        #     i, 100 * class_correct[i] / class_total[i]))
        
    train_avg_acc /= 2.
    val_avg_acc /= 2.
    
    if val_avg_acc > best_val_acc:
        best_val_acc = val_avg_acc
        torch.save(
            net.state_dict(),
            'model_{0}_{1}.pth'.format(epoch, best_val_acc)
        )
    
    print('Epoch %s, Train loss %.6f, Train acc %.3f, Train avg acc %.3f, Val avg acc %.3f'%(epoch, train_loss, train_acc, train_avg_acc, val_avg_acc))
# Out:
# Epoch 0, Train loss 0.626194, Train acc 62.996, Train avg acc 65.958, Val avg acc 69.616
# Epoch 1, Train loss 0.584932, Train acc 63.967, Train avg acc 69.161, Val avg acc 68.381
# Epoch 2, Train loss 0.570595, Train acc 67.050, Train avg acc 70.148, Val avg acc 67.146
# Epoch 3, Train loss 0.558854, Train acc 69.072, Train avg acc 69.772, Val avg acc 68.946
# Epoch 4, Train loss 0.553670, Train acc 71.590, Train avg acc 71.338, Val avg acc 71.745
# Epoch 5, Train loss 0.546879, Train acc 71.632, Train avg acc 71.926, Val avg acc 71.021
# Epoch 6, Train loss 0.540119, Train acc 72.614, Train avg acc 72.027, Val avg acc 70.360
# Epoch 7, Train loss 0.536023, Train acc 71.711, Train avg acc 71.515, Val avg acc 70.272
# Epoch 8, Train loss 0.534918, Train acc 72.994, Train avg acc 71.908, Val avg acc 72.950
# Epoch 9, Train loss 0.533707, Train acc 72.873, Train avg acc 72.269, Val avg acc 72.836
# Epoch 10, Train loss 0.525268, Train acc 74.367, Train avg acc 72.201, Val avg acc 72.038
# Epoch 11, Train loss 0.521007, Train acc 74.045, Train avg acc 72.628, Val avg acc 71.217
# Epoch 12, Train loss 0.516163, Train acc 73.960, Train avg acc 72.823, Val avg acc 72.682
# Epoch 13, Train loss 0.509810, Train acc 74.578, Train avg acc 73.939, Val avg acc 72.072
# Epoch 14, Train loss 0.508628, Train acc 74.245, Train avg acc 73.729, Val avg acc 71.559
# Epoch 15, Train loss 0.507091, Train acc 73.913, Train avg acc 73.310, Val avg acc 75.645
# Epoch 16, Train loss 0.502802, Train acc 74.805, Train avg acc 73.669, Val avg acc 75.873
# Epoch 17, Train loss 0.495592, Train acc 74.425, Train avg acc 73.767, Val avg acc 76.418
# Epoch 18, Train loss 0.501178, Train acc 74.726, Train avg acc 74.154, Val avg acc 75.474
# Epoch 19, Train loss 0.494749, Train acc 74.889, Train avg acc 74.036, Val avg acc 73.577
# Epoch 20, Train loss 0.491501, Train acc 75.501, Train avg acc 74.153, Val avg acc 74.903
# Epoch 21, Train loss 0.488707, Train acc 75.274, Train avg acc 74.660, Val avg acc 72.739
# Epoch 22, Train loss 0.489986, Train acc 76.277, Train avg acc 74.436, Val avg acc 75.213
# Epoch 23, Train loss 0.490476, Train acc 75.443, Train avg acc 74.871, Val avg acc 77.013
# Epoch 24, Train loss 0.487027, Train acc 75.607, Train avg acc 74.656, Val avg acc 75.637
# Epoch 25, Train loss 0.484548, Train acc 75.792, Train avg acc 74.108, Val avg acc 72.471
# Epoch 26, Train loss 0.480611, Train acc 76.098, Train avg acc 74.677, Val avg acc 75.890
# Epoch 27, Train loss 0.483898, Train acc 76.193, Train avg acc 75.123, Val avg acc 74.537
# Epoch 28, Train loss 0.477876, Train acc 75.665, Train avg acc 75.414, Val avg acc 76.264
# Epoch 29, Train loss 0.478756, Train acc 76.336, Train avg acc 75.422, Val avg acc 74.065
# Epoch 30, Train loss 0.473787, Train acc 75.459, Train avg acc 75.346, Val avg acc 76.834
# Epoch 31, Train loss 0.473712, Train acc 76.119, Train avg acc 75.735, Val avg acc 76.810
# Epoch 32, Train loss 0.467775, Train acc 76.510, Train avg acc 75.598, Val avg acc 75.303
# Epoch 33, Train loss 0.474624, Train acc 76.188, Train avg acc 75.683, Val avg acc 71.405
# Epoch 34, Train loss 0.475346, Train acc 76.050, Train avg acc 75.334, Val avg acc 77.045
# Epoch 35, Train loss 0.472823, Train acc 76.336, Train avg acc 75.252, Val avg acc 76.728
# Epoch 36, Train loss 0.472480, Train acc 76.478, Train avg acc 75.596, Val avg acc 77.437
# Epoch 37, Train loss 0.466972, Train acc 77.982, Train avg acc 75.859, Val avg acc 75.793
# Epoch 38, Train loss 0.478075, Train acc 77.555, Train avg acc 75.449, Val avg acc 76.785
# Epoch 39, Train loss 0.469782, Train acc 77.486, Train avg acc 75.922, Val avg acc 75.555
# Epoch 40, Train loss 0.468322, Train acc 77.792, Train avg acc 76.304, Val avg acc 74.465
# Epoch 41, Train loss 0.461276, Train acc 78.304, Train avg acc 76.005, Val avg acc 78.136
# Epoch 42, Train loss 0.468081, Train acc 77.418, Train avg acc 75.789, Val avg acc 74.098
# Epoch 43, Train loss 0.467083, Train acc 77.069, Train avg acc 76.363, Val avg acc 76.068
# Epoch 44, Train loss 0.465083, Train acc 77.486, Train avg acc 76.145, Val avg acc 76.582
# Epoch 45, Train loss 0.466495, Train acc 78.363, Train avg acc 75.566, Val avg acc 73.716
# Epoch 46, Train loss 0.461233, Train acc 77.824, Train avg acc 76.127, Val avg acc 77.779
# Epoch 47, Train loss 0.462181, Train acc 77.650, Train avg acc 76.011, Val avg acc 77.038
# Epoch 48, Train loss 0.466273, Train acc 78.114, Train avg acc 76.584, Val avg acc 76.557
# Epoch 49, Train loss 0.456421, Train acc 78.030, Train avg acc 76.856, Val avg acc 73.319
# Epoch 50, Train loss 0.464620, Train acc 79.043, Train avg acc 75.915, Val avg acc 76.834
# Epoch 51, Train loss 0.458079, Train acc 78.294, Train avg acc 76.732, Val avg acc 76.842
# Epoch 52, Train loss 0.462699, Train acc 78.473, Train avg acc 76.467, Val avg acc 77.298
# Epoch 53, Train loss 0.461923, Train acc 78.046, Train avg acc 76.264, Val avg acc 77.608
# Epoch 54, Train loss 0.454915, Train acc 78.822, Train avg acc 76.678, Val avg acc 73.587
# Epoch 55, Train loss 0.452773, Train acc 79.165, Train avg acc 76.497, Val avg acc 76.931
# Epoch 56, Train loss 0.455840, Train acc 79.608, Train avg acc 76.371, Val avg acc 76.988
# Epoch 57, Train loss 0.460416, Train acc 77.845, Train avg acc 76.251, Val avg acc 77.380
# Epoch 58, Train loss 0.456097, Train acc 78.442, Train avg acc 76.740, Val avg acc 77.672
# Epoch 59, Train loss 0.454334, Train acc 78.204, Train avg acc 76.684, Val avg acc 78.560
# Epoch 60, Train loss 0.457877, Train acc 78.083, Train avg acc 76.350, Val avg acc 77.437
# Epoch 61, Train loss 0.460796, Train acc 79.096, Train avg acc 75.957, Val avg acc 75.726
# Epoch 62, Train loss 0.455256, Train acc 78.083, Train avg acc 76.930, Val avg acc 76.753
# Epoch 63, Train loss 0.451153, Train acc 79.999, Train avg acc 76.529, Val avg acc 76.395
# Epoch 64, Train loss 0.452710, Train acc 79.962, Train avg acc 77.112, Val avg acc 76.150
# Epoch 65, Train loss 0.452160, Train acc 78.442, Train avg acc 76.531, Val avg acc 76.916
# Epoch 66, Train loss 0.453848, Train acc 79.107, Train avg acc 76.544, Val avg acc 76.834
# Epoch 67, Train loss 0.444682, Train acc 79.286, Train avg acc 76.822, Val avg acc 76.810
# Epoch 68, Train loss 0.451327, Train acc 79.946, Train avg acc 76.415, Val avg acc 76.232
# Epoch 69, Train loss 0.452576, Train acc 78.912, Train avg acc 76.683, Val avg acc 76.810
# Epoch 70, Train loss 0.448293, Train acc 78.832, Train avg acc 77.100, Val avg acc 76.200
# Epoch 71, Train loss 0.448818, Train acc 78.748, Train avg acc 76.675, Val avg acc 76.988
# Epoch 72, Train loss 0.449409, Train acc 78.246, Train avg acc 76.848, Val avg acc 76.639
# Epoch 73, Train loss 0.448120, Train acc 78.975, Train avg acc 77.430, Val avg acc 75.451
# Epoch 74, Train loss 0.444997, Train acc 78.864, Train avg acc 76.895, Val avg acc 75.687
# Epoch 75, Train loss 0.448148, Train acc 78.721, Train avg acc 76.913, Val avg acc 75.890
# Epoch 76, Train loss 0.451419, Train acc 78.590, Train avg acc 76.812, Val avg acc 78.153
# Epoch 77, Train loss 0.446967, Train acc 78.721, Train avg acc 77.419, Val avg acc 75.605
# Epoch 78, Train loss 0.450387, Train acc 79.181, Train avg acc 77.178, Val avg acc 76.956
# Epoch 79, Train loss 0.451358, Train acc 78.732, Train avg acc 77.164, Val avg acc 77.551
# Epoch 80, Train loss 0.443799, Train acc 80.020, Train avg acc 77.502, Val avg acc 78.503
# Epoch 81, Train loss 0.444653, Train acc 79.856, Train avg acc 77.449, Val avg acc 77.347
# Epoch 82, Train loss 0.444455, Train acc 79.592, Train avg acc 76.787, Val avg acc 76.329
# Epoch 83, Train loss 0.446726, Train acc 79.086, Train avg acc 77.171, Val avg acc 76.435
# Epoch 84, Train loss 0.442245, Train acc 79.096, Train avg acc 77.236, Val avg acc 77.323
# Epoch 85, Train loss 0.443323, Train acc 79.740, Train avg acc 77.073, Val avg acc 74.970
# Epoch 86, Train loss 0.440175, Train acc 79.239, Train avg acc 77.900, Val avg acc 77.526
# Epoch 87, Train loss 0.443082, Train acc 79.492, Train avg acc 77.326, Val avg acc 77.429
# Epoch 88, Train loss 0.440630, Train acc 79.249, Train avg acc 77.170, Val avg acc 76.631
# Epoch 89, Train loss 0.439850, Train acc 79.577, Train avg acc 77.140, Val avg acc 76.574
# Epoch 90, Train loss 0.440351, Train acc 79.012, Train avg acc 77.740, Val avg acc 77.576
# Epoch 91, Train loss 0.442198, Train acc 79.999, Train avg acc 77.475, Val avg acc 75.443
# Epoch 92, Train loss 0.440416, Train acc 80.110, Train avg acc 77.929, Val avg acc 77.404
# Epoch 93, Train loss 0.441361, Train acc 80.316, Train avg acc 78.560, Val avg acc 77.372
# Epoch 94, Train loss 0.441473, Train acc 80.046, Train avg acc 77.865, Val avg acc 76.542
# Epoch 95, Train loss 0.444217, Train acc 79.783, Train avg acc 77.543, Val avg acc 76.720
# Epoch 96, Train loss 0.439320, Train acc 80.268, Train avg acc 77.502, Val avg acc 77.095
# Epoch 97, Train loss 0.441954, Train acc 79.624, Train avg acc 77.628, Val avg acc 77.330
# Epoch 98, Train loss 0.439826, Train acc 78.727, Train avg acc 78.327, Val avg acc 76.338
# Epoch 99, Train loss 0.437266, Train acc 80.442, Train avg acc 77.381, Val avg acc 78.203
# Epoch 100, Train loss 0.438737, Train acc 80.163, Train avg acc 77.600, Val avg acc 77.771
# Epoch 101, Train loss 0.434587, Train acc 79.846, Train avg acc 77.257, Val avg acc 75.972
# Epoch 102, Train loss 0.438993, Train acc 79.730, Train avg acc 78.019, Val avg acc 77.990
# Epoch 103, Train loss 0.437039, Train acc 79.091, Train avg acc 77.552, Val avg acc 77.005
# Epoch 104, Train loss 0.439845, Train acc 80.463, Train avg acc 77.654, Val avg acc 77.055
# Epoch 105, Train loss 0.436188, Train acc 80.506, Train avg acc 77.958, Val avg acc 75.939
# Epoch 106, Train loss 0.435879, Train acc 80.126, Train avg acc 78.205, Val avg acc 75.907
# Epoch 107, Train loss 0.432964, Train acc 80.263, Train avg acc 77.648, Val avg acc 76.371
# Epoch 108, Train loss 0.433631, Train acc 79.693, Train avg acc 77.880, Val avg acc 76.428
# Epoch 109, Train loss 0.437417, Train acc 80.289, Train avg acc 77.379, Val avg acc 78.674
# Epoch 110, Train loss 0.435494, Train acc 80.068, Train avg acc 77.854, Val avg acc 77.144
# Epoch 111, Train loss 0.438101, Train acc 80.020, Train avg acc 77.687, Val avg acc 77.747
# Epoch 112, Train loss 0.435057, Train acc 79.582, Train avg acc 78.087, Val avg acc 77.330
# Epoch 113, Train loss 0.432065, Train acc 79.841, Train avg acc 78.049, Val avg acc 77.055
# Epoch 114, Train loss 0.433885, Train acc 81.023, Train avg acc 78.099, Val avg acc 78.007
# Epoch 115, Train loss 0.437732, Train acc 79.445, Train avg acc 77.819, Val avg acc 77.290
# Epoch 116, Train loss 0.433122, Train acc 80.136, Train avg acc 78.010, Val avg acc 77.176
# Epoch 117, Train loss 0.434985, Train acc 80.548, Train avg acc 77.664, Val avg acc 76.175
# Epoch 118, Train loss 0.430415, Train acc 79.614, Train avg acc 78.549, Val avg acc 78.976
# Epoch 119, Train loss 0.429965, Train acc 81.134, Train avg acc 78.760, Val avg acc 77.323
# Epoch 120, Train loss 0.430023, Train acc 80.004, Train avg acc 78.339, Val avg acc 78.267
# Epoch 121, Train loss 0.435445, Train acc 80.332, Train avg acc 77.798, Val avg acc 76.061
# Epoch 122, Train loss 0.430062, Train acc 80.954, Train avg acc 78.559, Val avg acc 77.640
# Epoch 123, Train loss 0.426501, Train acc 79.888, Train avg acc 77.934, Val avg acc 75.858
# Epoch 124, Train loss 0.429420, Train acc 80.347, Train avg acc 78.281, Val avg acc 78.056
# Epoch 125, Train loss 0.433022, Train acc 79.851, Train avg acc 78.247, Val avg acc 78.609
# Epoch 126, Train loss 0.431661, Train acc 80.780, Train avg acc 78.078, Val avg acc 77.258
# Epoch 127, Train loss 0.428975, Train acc 80.606, Train avg acc 78.562, Val avg acc 76.859
# Epoch 128, Train loss 0.428191, Train acc 80.495, Train avg acc 78.027, Val avg acc 79.008
# Epoch 129, Train loss 0.428426, Train acc 80.627, Train avg acc 78.359, Val avg acc 77.152
# Epoch 130, Train loss 0.427515, Train acc 80.231, Train avg acc 78.329, Val avg acc 76.867
# Epoch 131, Train loss 0.426728, Train acc 80.374, Train avg acc 78.718, Val avg acc 77.625
# Epoch 132, Train loss 0.426871, Train acc 81.129, Train avg acc 78.513, Val avg acc 80.082
# Epoch 133, Train loss 0.426010, Train acc 80.933, Train avg acc 78.570, Val avg acc 77.380
# Epoch 134, Train loss 0.428005, Train acc 80.295, Train avg acc 78.689, Val avg acc 78.121
# Epoch 135, Train loss 0.424643, Train acc 80.516, Train avg acc 77.898, Val avg acc 77.722
# Epoch 136, Train loss 0.427891, Train acc 80.379, Train avg acc 77.994, Val avg acc 77.233
# Epoch 137, Train loss 0.429714, Train acc 80.712, Train avg acc 78.701, Val avg acc 77.437
# Epoch 138, Train loss 0.425858, Train acc 81.524, Train avg acc 78.817, Val avg acc 78.235
# Epoch 139, Train loss 0.422581, Train acc 81.387, Train avg acc 78.364, Val avg acc 78.381
# Epoch 140, Train loss 0.424212, Train acc 80.463, Train avg acc 78.195, Val avg acc 78.691
# Epoch 141, Train loss 0.420760, Train acc 80.875, Train avg acc 78.864, Val avg acc 76.998
# Epoch 142, Train loss 0.424788, Train acc 81.049, Train avg acc 78.455, Val avg acc 77.494
# Epoch 143, Train loss 0.426155, Train acc 80.891, Train avg acc 78.398, Val avg acc 76.224
# Epoch 144, Train loss 0.422258, Train acc 80.627, Train avg acc 78.143, Val avg acc 77.119
# Epoch 145, Train loss 0.424903, Train acc 80.664, Train avg acc 78.534, Val avg acc 75.687
# Epoch 146, Train loss 0.425704, Train acc 80.759, Train avg acc 78.275, Val avg acc 77.682
# Epoch 147, Train loss 0.421164, Train acc 81.387, Train avg acc 78.520, Val avg acc 77.714
# Epoch 148, Train loss 0.424934, Train acc 81.023, Train avg acc 78.515, Val avg acc 78.227
# Epoch 149, Train loss 0.422204, Train acc 81.466, Train avg acc 78.927, Val avg acc 78.894
# Epoch 150, Train loss 0.424939, Train acc 80.764, Train avg acc 78.582, Val avg acc 77.152
# Epoch 151, Train loss 0.421465, Train acc 80.353, Train avg acc 78.484, Val avg acc 77.779
# Epoch 152, Train loss 0.422506, Train acc 80.099, Train avg acc 78.272, Val avg acc 78.081
# Epoch 153, Train loss 0.427262, Train acc 81.086, Train avg acc 78.401, Val avg acc 77.437
# Epoch 154, Train loss 0.418464, Train acc 80.500, Train avg acc 78.312, Val avg acc 76.713
# Epoch 155, Train loss 0.416409, Train acc 80.743, Train avg acc 79.134, Val avg acc 77.576
# Epoch 156, Train loss 0.423466, Train acc 81.308, Train avg acc 78.358, Val avg acc 79.358
# Epoch 157, Train loss 0.417693, Train acc 80.569, Train avg acc 79.254, Val avg acc 78.805
# Epoch 158, Train loss 0.420185, Train acc 81.377, Train avg acc 78.032, Val avg acc 77.290
# Epoch 159, Train loss 0.421066, Train acc 81.493, Train avg acc 78.889, Val avg acc 77.999
# Epoch 160, Train loss 0.420290, Train acc 81.176, Train avg acc 79.192, Val avg acc 79.782
# Epoch 161, Train loss 0.420143, Train acc 81.540, Train avg acc 78.707, Val avg acc 76.249
# Epoch 162, Train loss 0.418170, Train acc 82.100, Train avg acc 79.093, Val avg acc 76.542
# Epoch 163, Train loss 0.420480, Train acc 81.234, Train avg acc 79.037, Val avg acc 76.688
# Epoch 164, Train loss 0.417151, Train acc 81.055, Train avg acc 79.237, Val avg acc 76.452
# Epoch 165, Train loss 0.415597, Train acc 80.997, Train avg acc 78.865, Val avg acc 76.338
# Epoch 166, Train loss 0.411817, Train acc 81.213, Train avg acc 78.923, Val avg acc 75.972
# Epoch 167, Train loss 0.417436, Train acc 81.498, Train avg acc 79.693, Val avg acc 77.486
# Epoch 168, Train loss 0.416712, Train acc 81.477, Train avg acc 79.140, Val avg acc 78.284
# Epoch 169, Train loss 0.413377, Train acc 81.292, Train avg acc 78.868, Val avg acc 78.659
# Epoch 170, Train loss 0.415644, Train acc 80.558, Train avg acc 78.869, Val avg acc 78.292
# Epoch 171, Train loss 0.417121, Train acc 81.477, Train avg acc 78.969, Val avg acc 77.625
# Epoch 172, Train loss 0.415458, Train acc 81.757, Train avg acc 78.981, Val avg acc 77.087
# Epoch 173, Train loss 0.415132, Train acc 81.788, Train avg acc 79.652, Val avg acc 76.909
# Epoch 174, Train loss 0.414364, Train acc 82.944, Train avg acc 78.980, Val avg acc 77.112
# Epoch 175, Train loss 0.422490, Train acc 81.023, Train avg acc 78.574, Val avg acc 77.201
# Epoch 176, Train loss 0.415526, Train acc 81.662, Train avg acc 79.092, Val avg acc 78.431
# Epoch 177, Train loss 0.417626, Train acc 81.287, Train avg acc 79.171, Val avg acc 77.340
# Epoch 178, Train loss 0.411486, Train acc 81.978, Train avg acc 79.183, Val avg acc 78.007
# Epoch 179, Train loss 0.418401, Train acc 80.859, Train avg acc 79.307, Val avg acc 77.062
# Epoch 180, Train loss 0.413829, Train acc 81.662, Train avg acc 78.907, Val avg acc 78.944
# Epoch 181, Train loss 0.412610, Train acc 82.422, Train avg acc 78.631, Val avg acc 76.859
# Epoch 182, Train loss 0.417009, Train acc 82.010, Train avg acc 78.776, Val avg acc 77.900
# Epoch 183, Train loss 0.413594, Train acc 81.989, Train avg acc 79.219, Val avg acc 79.326
# Epoch 184, Train loss 0.408314, Train acc 81.994, Train avg acc 79.437, Val avg acc 76.281
# Epoch 185, Train loss 0.409784, Train acc 82.021, Train avg acc 78.946, Val avg acc 76.485
# Epoch 186, Train loss 0.416259, Train acc 82.221, Train avg acc 79.382, Val avg acc 78.585
# Epoch 187, Train loss 0.407275, Train acc 81.609, Train avg acc 79.941, Val avg acc 76.909
# Epoch 188, Train loss 0.415974, Train acc 82.332, Train avg acc 78.835, Val avg acc 77.486
# Epoch 189, Train loss 0.414280, Train acc 82.242, Train avg acc 78.985, Val avg acc 78.292
# Epoch 190, Train loss 0.411932, Train acc 81.551, Train avg acc 79.439, Val avg acc 75.768
# Epoch 191, Train loss 0.408817, Train acc 82.385, Train avg acc 79.360, Val avg acc 79.350
# Epoch 192, Train loss 0.407677, Train acc 81.788, Train avg acc 79.287, Val avg acc 79.204
# Epoch 193, Train loss 0.410191, Train acc 82.248, Train avg acc 79.203, Val avg acc 77.893
# Epoch 194, Train loss 0.413165, Train acc 82.015, Train avg acc 79.196, Val avg acc 77.055
# Epoch 195, Train loss 0.409689, Train acc 81.472, Train avg acc 79.715, Val avg acc 78.577
# Epoch 196, Train loss 0.408393, Train acc 81.947, Train avg acc 79.329, Val avg acc 77.404
# Epoch 197, Train loss 0.410957, Train acc 82.147, Train avg acc 78.822, Val avg acc 78.292
# Epoch 198, Train loss 0.407382, Train acc 81.783, Train avg acc 79.351, Val avg acc 78.488
# Epoch 199, Train loss 0.408395, Train acc 82.052, Train avg acc 79.527, Val avg acc 77.657
# Epoch 200, Train loss 0.400785, Train acc 82.411, Train avg acc 79.434, Val avg acc 77.804
# Epoch 201, Train loss 0.413420, Train acc 82.348, Train avg acc 78.761, Val avg acc 79.187
# Epoch 202, Train loss 0.408924, Train acc 80.870, Train avg acc 79.602, Val avg acc 78.203
# Epoch 203, Train loss 0.410877, Train acc 82.554, Train avg acc 79.742, Val avg acc 77.771
# Epoch 204, Train loss 0.410955, Train acc 82.195, Train avg acc 79.553, Val avg acc 78.056
# Epoch 205, Train loss 0.410051, Train acc 81.804, Train avg acc 79.318, Val avg acc 78.146
# Epoch 206, Train loss 0.411248, Train acc 81.298, Train avg acc 79.200, Val avg acc 77.315
# Epoch 207, Train loss 0.407351, Train acc 82.010, Train avg acc 79.237, Val avg acc 78.488
# Epoch 208, Train loss 0.408176, Train acc 82.348, Train avg acc 79.258, Val avg acc 79.782
# Epoch 209, Train loss 0.405804, Train acc 82.084, Train avg acc 79.745, Val avg acc 78.056
# Epoch 210, Train loss 0.408498, Train acc 81.604, Train avg acc 79.380, Val avg acc 78.284
# Epoch 211, Train loss 0.411137, Train acc 82.538, Train avg acc 78.944, Val avg acc 78.520
# Epoch 212, Train loss 0.405189, Train acc 82.348, Train avg acc 79.481, Val avg acc 78.292
# Epoch 213, Train loss 0.405649, Train acc 81.693, Train avg acc 79.585, Val avg acc 78.113
# Epoch 214, Train loss 0.405647, Train acc 83.066, Train avg acc 79.804, Val avg acc 78.210
# Epoch 215, Train loss 0.401632, Train acc 82.622, Train avg acc 79.667, Val avg acc 78.381
# Epoch 216, Train loss 0.404895, Train acc 81.978, Train avg acc 79.689, Val avg acc 78.512
# Epoch 217, Train loss 0.405339, Train acc 82.454, Train avg acc 80.005, Val avg acc 78.773
# Epoch 218, Train loss 0.402501, Train acc 82.765, Train avg acc 80.117, Val avg acc 77.568
# Epoch 219, Train loss 0.405611, Train acc 82.100, Train avg acc 79.227, Val avg acc 77.340
# Epoch 220, Train loss 0.407079, Train acc 81.910, Train avg acc 79.368, Val avg acc 76.452
# Epoch 221, Train loss 0.406586, Train acc 82.496, Train avg acc 79.880, Val avg acc 79.147
# Epoch 222, Train loss 0.406951, Train acc 81.788, Train avg acc 79.630, Val avg acc 78.374
# Epoch 223, Train loss 0.403733, Train acc 81.910, Train avg acc 79.703, Val avg acc 78.830
# Epoch 224, Train loss 0.396807, Train acc 82.765, Train avg acc 79.707, Val avg acc 79.579
# Epoch 225, Train loss 0.406083, Train acc 82.987, Train avg acc 79.352, Val avg acc 77.258
# Epoch 226, Train loss 0.401697, Train acc 81.503, Train avg acc 79.653, Val avg acc 78.113
# Epoch 227, Train loss 0.402410, Train acc 82.448, Train avg acc 79.927, Val avg acc 75.451
# Epoch 228, Train loss 0.405273, Train acc 81.319, Train avg acc 79.150, Val avg acc 77.999
# Epoch 229, Train loss 0.407514, Train acc 83.119, Train avg acc 79.040, Val avg acc 78.292
# Epoch 230, Train loss 0.402180, Train acc 82.786, Train avg acc 79.697, Val avg acc 78.374
# Epoch 231, Train loss 0.406888, Train acc 82.786, Train avg acc 79.786, Val avg acc 80.124
# Epoch 232, Train loss 0.401212, Train acc 82.580, Train avg acc 79.377, Val avg acc 78.349
# Epoch 233, Train loss 0.399846, Train acc 82.707, Train avg acc 79.654, Val avg acc 78.317
# Epoch 234, Train loss 0.403703, Train acc 82.591, Train avg acc 79.457, Val avg acc 77.771
# Epoch 235, Train loss 0.403282, Train acc 82.686, Train avg acc 79.731, Val avg acc 78.716
# Epoch 236, Train loss 0.402979, Train acc 82.522, Train avg acc 79.464, Val avg acc 78.862
# Epoch 237, Train loss 0.397760, Train acc 82.559, Train avg acc 79.305, Val avg acc 77.486
# Epoch 238, Train loss 0.402662, Train acc 82.681, Train avg acc 79.915, Val avg acc 78.594
# Epoch 239, Train loss 0.401280, Train acc 83.098, Train avg acc 79.992, Val avg acc 78.064
# Epoch 240, Train loss 0.397632, Train acc 82.575, Train avg acc 79.738, Val avg acc 77.975
# Epoch 241, Train loss 0.395388, Train acc 82.580, Train avg acc 79.852, Val avg acc 77.836
# Epoch 242, Train loss 0.396670, Train acc 82.279, Train avg acc 79.785, Val avg acc 76.884
# Epoch 243, Train loss 0.397258, Train acc 82.010, Train avg acc 79.586, Val avg acc 77.258
# Epoch 244, Train loss 0.403708, Train acc 82.005, Train avg acc 79.919, Val avg acc 78.488
# Epoch 245, Train loss 0.394414, Train acc 82.380, Train avg acc 80.529, Val avg acc 78.024
# Epoch 246, Train loss 0.397814, Train acc 82.475, Train avg acc 80.124, Val avg acc 77.804
# Epoch 247, Train loss 0.398491, Train acc 82.174, Train avg acc 80.315, Val avg acc 77.030
# Epoch 248, Train loss 0.394621, Train acc 82.348, Train avg acc 79.991, Val avg acc 78.032
# Epoch 249, Train loss 0.397110, Train acc 82.337, Train avg acc 80.173, Val avg acc 77.771
# Epoch 250, Train loss 0.402066, Train acc 82.427, Train avg acc 79.961, Val avg acc 77.030
# Epoch 251, Train loss 0.398931, Train acc 82.538, Train avg acc 79.821, Val avg acc 79.236
# Epoch 252, Train loss 0.398195, Train acc 81.730, Train avg acc 79.833, Val avg acc 77.258
# Epoch 253, Train loss 0.394134, Train acc 82.839, Train avg acc 80.201, Val avg acc 78.919
# Epoch 254, Train loss 0.397904, Train acc 82.274, Train avg acc 79.812, Val avg acc 76.827
# Epoch 255, Train loss 0.391545, Train acc 82.823, Train avg acc 80.332, Val avg acc 77.372
# Epoch 256, Train loss 0.394955, Train acc 82.781, Train avg acc 80.596, Val avg acc 79.179
# Epoch 257, Train loss 0.391163, Train acc 82.586, Train avg acc 79.974, Val avg acc 76.770
# Epoch 258, Train loss 0.394748, Train acc 82.971, Train avg acc 80.474, Val avg acc 76.948
# Epoch 259, Train loss 0.397452, Train acc 83.129, Train avg acc 80.232, Val avg acc 78.374
# Epoch 260, Train loss 0.399159, Train acc 82.570, Train avg acc 80.030, Val avg acc 78.146
# Epoch 261, Train loss 0.399231, Train acc 82.765, Train avg acc 79.641, Val avg acc 77.397
# Epoch 262, Train loss 0.391806, Train acc 82.649, Train avg acc 80.105, Val avg acc 77.804
# Epoch 263, Train loss 0.391356, Train acc 83.330, Train avg acc 80.512, Val avg acc 77.454
# Epoch 264, Train loss 0.393537, Train acc 82.343, Train avg acc 79.685, Val avg acc 77.454
# Epoch 265, Train loss 0.394259, Train acc 82.047, Train avg acc 80.407, Val avg acc 78.292
# Epoch 266, Train loss 0.389310, Train acc 82.717, Train avg acc 80.172, Val avg acc 78.032
# Epoch 267, Train loss 0.393096, Train acc 83.050, Train avg acc 80.398, Val avg acc 76.631
# Epoch 268, Train loss 0.394746, Train acc 82.184, Train avg acc 80.099, Val avg acc 79.001
# Epoch 269, Train loss 0.397352, Train acc 82.337, Train avg acc 80.008, Val avg acc 77.861
# Epoch 270, Train loss 0.394768, Train acc 83.166, Train avg acc 80.573, Val avg acc 77.055
# Epoch 271, Train loss 0.396801, Train acc 83.045, Train avg acc 80.156, Val avg acc 77.707
# Epoch 272, Train loss 0.397449, Train acc 83.483, Train avg acc 79.823, Val avg acc 78.659
# Epoch 273, Train loss 0.395873, Train acc 82.902, Train avg acc 80.080, Val avg acc 78.585
# Epoch 274, Train loss 0.397708, Train acc 82.601, Train avg acc 79.863, Val avg acc 76.941
# Epoch 275, Train loss 0.393851, Train acc 82.417, Train avg acc 80.401, Val avg acc 77.315
# Epoch 276, Train loss 0.388424, Train acc 82.200, Train avg acc 80.415, Val avg acc 79.229
# Epoch 277, Train loss 0.393997, Train acc 82.892, Train avg acc 80.362, Val avg acc 77.372
# Epoch 278, Train loss 0.396241, Train acc 82.929, Train avg acc 79.856, Val avg acc 77.657
# Epoch 279, Train loss 0.393764, Train acc 83.034, Train avg acc 79.676, Val avg acc 77.861
# Epoch 280, Train loss 0.389702, Train acc 82.812, Train avg acc 80.164, Val avg acc 77.950
# Epoch 281, Train loss 0.387515, Train acc 81.788, Train avg acc 80.224, Val avg acc 76.941
# Epoch 282, Train loss 0.388529, Train acc 82.770, Train avg acc 80.415, Val avg acc 79.212
# Epoch 283, Train loss 0.391320, Train acc 82.855, Train avg acc 80.143, Val avg acc 78.406
# Epoch 284, Train loss 0.390515, Train acc 82.855, Train avg acc 80.246, Val avg acc 78.431
# Epoch 285, Train loss 0.389366, Train acc 82.944, Train avg acc 80.124, Val avg acc 78.235
# Epoch 286, Train loss 0.390654, Train acc 82.865, Train avg acc 80.357, Val avg acc 77.975
# Epoch 287, Train loss 0.397135, Train acc 82.966, Train avg acc 80.092, Val avg acc 77.950
# Epoch 288, Train loss 0.387814, Train acc 81.730, Train avg acc 80.394, Val avg acc 78.780
# Epoch 289, Train loss 0.390412, Train acc 82.517, Train avg acc 80.693, Val avg acc 77.087
# Epoch 290, Train loss 0.389878, Train acc 82.216, Train avg acc 80.463, Val avg acc 78.032
# Epoch 291, Train loss 0.391807, Train acc 83.251, Train avg acc 80.134, Val avg acc 78.634
# Epoch 292, Train loss 0.391141, Train acc 82.765, Train avg acc 80.838, Val avg acc 78.349
# Epoch 293, Train loss 0.388507, Train acc 83.377, Train avg acc 80.739, Val avg acc 77.290
# Epoch 294, Train loss 0.387966, Train acc 83.346, Train avg acc 80.379, Val avg acc 78.398
# Epoch 295, Train loss 0.394635, Train acc 82.427, Train avg acc 80.443, Val avg acc 78.919
# Epoch 296, Train loss 0.388236, Train acc 82.987, Train avg acc 80.400, Val avg acc 77.543
# Epoch 297, Train loss 0.388139, Train acc 82.871, Train avg acc 80.285, Val avg acc 79.464
# Epoch 298, Train loss 0.388548, Train acc 82.791, Train avg acc 80.189, Val avg acc 78.976
# Epoch 299, Train loss 0.397201, Train acc 82.744, Train avg acc 79.912, Val avg acc 79.464

# %%
testRaw = pd.read_csv('test_data_unlabeled.csv')
jobId = testRaw.iloc[:, 0].values
testData = testRaw.iloc[:, 1:].values

# %%
net.eval()
# Out:
# MyNet(
#   (linear1): Linear(in_features=4, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=128, bias=True)
#   (linear3): Linear(in_features=128, out_features=2, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
net.load_state_dict(torch.load('/content/model_132_80.08201563380088.pth'))
# Out:
# <All keys matched successfully>

# %%
sc = StandardScaler()
predicted_output = net(torch.tensor(sc.fit_transform(testData), dtype=torch.float32).cuda())
_, pred = torch.max(predicted_output, 1)

# %%
a = pd.DataFrame({'job_id': pd.Series(jobId),'failed': pd.Series(pred.cpu().numpy())})

# %%
a['failed'].sum()

# %%
a.to_csv('1.csv', index=False)
